# %% [markdown]
# #Scope
# The scope of this code includes:
#
# 1. Authenticating and initializing the GEE API.
# 2. Retrieving and processing satellite imagery data - SAR(Sentinel-1)
# 3. Merging various environmental factors and ASI(maritime)
# 5. Exporting the results to Google Drive.

# %% [markdown]
# #Introduction
#
# * This Python script helps to analyze SAR for oil spill over time using Google Earth Engine (GEE). The results are exported to Google Drive in CSV format for further analysis.
#
# * The code has been converted from Google Earth Engine JavaScript to Python using the **geemap** package, which simplifies the process of working with GEE in Python and enables easy conversion of scripts from JavaScript to Python.

# %%
#!pip install geemap
#!pip install earthengine-api

# %%
#Import required libraries
import ee
import pandas as pd


ee.Authenticate()
ee.Initialize(project='ee-pranalitalla8')

# %%
#import os
#os.environ['EE_PROJECT_ID'] = 'ee-pranalitalla8'
#ee.Initialize(project=os.getenv('EE_PROJECT_ID'))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Mounted at /content/drive

# %%
import geemap
from datetime import datetime

# %% [markdown]
# ## Geemap
# Geemap is a Python package for interactive geospatial analysis and visualization with Google Earth Engine (GEE), helps for existing GEE users who would like to transition from the GEE JavaScript API to Python API. The automated JavaScript-to-Python conversion module of the geemap package can greatly reduce the time needed to convert existing GEE JavaScripts to Python scripts and Jupyter notebooks.
#
# [geemap.org](https://geemap.org)

# %%
m = geemap.Map()
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# ### Variables and collections
#  Various collections and images required for our analysis in Google Earth Engine (GEE). These collections include SAR (Sentinel-1- C band), JRC Water History.

# %%
ROI = ee.Geometry.Rectangle([-77.3, 36.8, -75, 39.7])
start_date = ee.Date('2015-01-01')
end_date = ee.Date('2025-12-31')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Get Available SAR Dates

# %%
def get_available_sar_dates(roi, start, end):
    #Get all available SAR dates for the ROI and time range
    sarCol_all = ee.ImageCollection('COPERNICUS/S1_GRD') \
        .filterBounds(roi) \
        .filterDate(start, end) \
        .filter(ee.Filter.eq('instrumentMode', 'IW')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH'))

    # Get unique dates
    dates = sarCol_all.aggregate_array('system:time_start') \
        .map(lambda x: ee.Date(x).format('YYYY-MM-dd')) \
        .distinct() \
        .sort()

    return dates.getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Single-Date Processing Function

# %%
def process_sar_date(date_str, roi):
    #Process SAR data for a single date
    try:
        date = ee.Date(date_str)

        # SAR Setup
        sarCol = ee.ImageCollection('COPERNICUS/S1_GRD') \
            .filterBounds(roi) \
            .filterDate(date, date.advance(1,'day')) \
            .filter(ee.Filter.eq('instrumentMode', 'IW')) \
            .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
            .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH'))

        # Check if any images exist
        if sarCol.size().getInfo() == 0:
            print(f'No SAR images for {date_str}')
            return None

        # Single SAR composite
        sar = sarCol.median().clip(roi)
        vhvv = sar.select('VH').divide(sar.select('VV')).rename('VH_VV_ratio')

        desc = sarCol.filter(ee.Filter.eq('orbitProperties_pass', 'DESCENDING')).size()
        asc = sarCol.filter(ee.Filter.eq('orbitProperties_pass', 'ASCENDING')).size()
        orbitNum = ee.Algorithms.If(desc.gt(asc), 1, 0)
        orbitName = ee.String(ee.Algorithms.If(desc.gt(asc), 'DESC', 'ASC'))
        orbitDirBand = ee.Image.constant(orbitNum).clip(roi).rename('orbit_direction')

        # JRC Water Mask
        jrcWater = ee.ImageCollection('JRC/GSW1_4/YearlyHistory') \
            .filterDate('2021-01-01', '2021-12-31') \
            .select('waterClass') \
            .mosaic() \
            .clip(roi) \
            .gte(3)

        # Masks
        oilMask = sar.select('VV').lt(-22).And(jrcWater)
        nonOilWaterMask = sar.select('VV').gte(-22).And(sar.select('VV').gt(-18)).And(jrcWater)

        # Stack features
        allFeatures = sar.select(['VV', 'VH', 'angle']) \
            .addBands(vhvv) \
            .addBands(orbitDirBand)

        # Labeling function
        def addBasicCols(feature, label):
            coords = feature.geometry().coordinates()
            properties = {
                'oil_candidate': label,
                'date': date.format('YYYY-MM-dd'),
                'latitude': ee.Number(coords.get(1)),
                'longitude': ee.Number(coords.get(0)),
                'orbit_direction': orbitNum,
                'orbit_type': orbitName,
                'VV': feature.get('VV'),
                'VH': feature.get('VH'),
                'angle': feature.get('angle'),
                'VH_VV_ratio': feature.get('VH_VV_ratio')
            }
            return ee.Feature(feature.geometry(), properties)

        # Sample points
        sampledOilPoints = allFeatures \
            .updateMask(oilMask) \
            .sample(region=roi, scale=30, numPixels=500, seed=101, geometries=True) \
            .map(lambda f: addBasicCols(f, 1))

        sampledWaterPoints = allFeatures \
            .updateMask(nonOilWaterMask) \
            .sample(region=roi, scale=30, numPixels=500, seed=201, geometries=True) \
            .map(lambda f: addBasicCols(f, 0))

        # Combine
        allLabeledPoints = sampledOilPoints.merge(sampledWaterPoints)

        return allLabeledPoints

    except Exception as e:
        print(f'Error processing {date_str}: {e}')
        return None
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Automated Loop Processing

# %%
print("Getting available SAR dates...")
available_dates = get_available_sar_dates(ROI, start_date, end_date)
print(f"Found {len(available_dates)} available SAR dates")
print("First 10 dates:", available_dates[:10])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Getting available SAR dates...
# Found 549 available SAR dates
# First 10 dates: ['2015-03-10', '2015-03-17', '2015-08-25', '2015-09-18', '2016-04-09', '2016-04-16', '2016-07-02', '2016-07-09', '2016-09-24', '2016-10-01']

# %%
#Process multiple dates (adjust range as needed)
#dates_to_process = available_dates[:20]  # Process first 20 dates
dates_to_process = available_dates
all_results = []
successful_dates = []

for i, date_str in enumerate(dates_to_process):
    print(f'Processing {i+1}/{len(dates_to_process)}: {date_str}...')

    result = process_sar_date(date_str, ROI)

    if result is not None:
        all_results.append(result)
        successful_dates.append(date_str)
        print(f'{date_str} completed')
    else:
        print(f'{date_str} skipped')

print(f"\nSuccessfully processed {len(successful_dates)} dates")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing 1/549: 2015-03-10...
# 2015-03-10 completed
# Processing 2/549: 2015-03-17...
# 2015-03-17 completed
# Processing 3/549: 2015-08-25...
# 2015-08-25 completed
# Processing 4/549: 2015-09-18...
# 2015-09-18 completed
# Processing 5/549: 2016-04-09...
# 2016-04-09 completed
# Processing 6/549: 2016-04-16...
# 2016-04-16 completed
# Processing 7/549: 2016-07-02...
# 2016-07-02 completed
# Processing 8/549: 2016-07-09...
# 2016-07-09 completed
# Processing 9/549: 2016-09-24...
# 2016-09-24 completed
# Processing 10/549: 2016-10-01...
# 2016-10-01 completed
# Processing 11/549: 2016-10-06...
# 2016-10-06 completed
# Processing 12/549: 2016-10-08...
# 2016-10-08 completed
# Processing 13/549: 2016-10-13...
# 2016-10-13 completed
# Processing 14/549: 2016-10-18...
# 2016-10-18 completed
# Processing 15/549: 2016-10-25...
# 2016-10-25 completed
# Processing 16/549: 2016-10-30...
# 2016-10-30 completed
# Processing 17/549: 2016-11-06...
# 2016-11-06 completed
# Processing 18/549: 2016-11-11...
# 2016-11-11 completed
# Processing 19/549: 2016-11-18...
# 2016-11-18 completed
# Processing 20/549: 2016-11-23...
# 2016-11-23 completed
# Processing 21/549: 2016-11-30...
# 2016-11-30 completed
# Processing 22/549: 2016-12-05...
# 2016-12-05 completed
# Processing 23/549: 2016-12-12...
# 2016-12-12 completed
# Processing 24/549: 2016-12-17...
# 2016-12-17 completed
# Processing 25/549: 2016-12-24...
# 2016-12-24 completed
# Processing 26/549: 2016-12-29...
# 2016-12-29 completed
# Processing 27/549: 2017-01-05...
# 2017-01-05 completed
# Processing 28/549: 2017-01-10...
# 2017-01-10 completed
# Processing 29/549: 2017-01-17...
# 2017-01-17 completed
# Processing 30/549: 2017-01-22...
# 2017-01-22 completed
# Processing 31/549: 2017-01-29...
# 2017-01-29 completed
# Processing 32/549: 2017-02-03...
# 2017-02-03 completed
# Processing 33/549: 2017-02-10...
# 2017-02-10 completed
# Processing 34/549: 2017-02-15...
# 2017-02-15 completed
# Processing 35/549: 2017-02-22...
# 2017-02-22 completed
# Processing 36/549: 2017-02-27...
# 2017-02-27 completed
# Processing 37/549: 2017-03-11...
# 2017-03-11 completed
# Processing 38/549: 2017-03-18...
# 2017-03-18 completed
# Processing 39/549: 2017-03-23...
# 2017-03-23 completed
# Processing 40/549: 2017-03-30...
# 2017-03-30 completed
# Processing 41/549: 2017-04-04...
# 2017-04-04 completed
# Processing 42/549: 2017-04-11...
# 2017-04-11 completed
# Processing 43/549: 2017-04-16...
# 2017-04-16 completed
# Processing 44/549: 2017-04-23...
# 2017-04-23 completed
# Processing 45/549: 2017-04-28...
# 2017-04-28 completed
# Processing 46/549: 2017-05-05...
# 2017-05-05 completed
# Processing 47/549: 2017-05-10...
# 2017-05-10 completed
# Processing 48/549: 2017-05-17...
# 2017-05-17 completed
# Processing 49/549: 2017-05-22...
# 2017-05-22 completed
# Processing 50/549: 2017-05-29...
# 2017-05-29 completed
# Processing 51/549: 2017-06-03...
# 2017-06-03 completed
# Processing 52/549: 2017-06-10...
# 2017-06-10 completed
# Processing 53/549: 2017-06-15...
# 2017-06-15 completed
# Processing 54/549: 2017-06-22...
# 2017-06-22 completed
# Processing 55/549: 2017-06-27...
# 2017-06-27 completed
# Processing 56/549: 2017-07-04...
# 2017-07-04 completed
# Processing 57/549: 2017-07-09...
# 2017-07-09 completed
# Processing 58/549: 2017-07-16...
# 2017-07-16 completed
# Processing 59/549: 2017-07-21...
# 2017-07-21 completed
# Processing 60/549: 2017-07-28...
# 2017-07-28 completed
# Processing 61/549: 2017-08-02...
# 2017-08-02 completed
# Processing 62/549: 2017-08-09...
# 2017-08-09 completed
# Processing 63/549: 2017-08-14...
# 2017-08-14 completed
# Processing 64/549: 2017-08-21...
# 2017-08-21 completed
# Processing 65/549: 2017-08-26...
# 2017-08-26 completed
# Processing 66/549: 2017-09-02...
# 2017-09-02 completed
# Processing 67/549: 2017-09-14...
# 2017-09-14 completed
# Processing 68/549: 2017-09-19...
# 2017-09-19 completed
# Processing 69/549: 2017-09-26...
# 2017-09-26 completed
# Processing 70/549: 2017-10-01...
# 2017-10-01 completed
# Processing 71/549: 2017-10-08...
# 2017-10-08 completed
# Processing 72/549: 2017-10-13...
# 2017-10-13 completed
# Processing 73/549: 2017-10-20...
# 2017-10-20 completed
# Processing 74/549: 2017-10-25...
# 2017-10-25 completed
# Processing 75/549: 2017-11-01...
# 2017-11-01 completed
# Processing 76/549: 2017-11-06...
# 2017-11-06 completed
# Processing 77/549: 2017-11-13...
# 2017-11-13 completed
# Processing 78/549: 2017-11-18...
# 2017-11-18 completed
# Processing 79/549: 2017-11-25...
# 2017-11-25 completed
# Processing 80/549: 2017-11-30...
# 2017-11-30 completed
# Processing 81/549: 2017-12-07...
# 2017-12-07 completed
# Processing 82/549: 2017-12-12...
# 2017-12-12 completed
# Processing 83/549: 2017-12-19...
# 2017-12-19 completed
# Processing 84/549: 2017-12-24...
# 2017-12-24 completed
# Processing 85/549: 2017-12-31...
# 2017-12-31 completed
# Processing 86/549: 2018-01-05...
# 2018-01-05 completed
# Processing 87/549: 2018-01-12...
# 2018-01-12 completed
# Processing 88/549: 2018-01-24...
# 2018-01-24 completed
# Processing 89/549: 2018-01-29...
# 2018-01-29 completed
# Processing 90/549: 2018-02-05...
# 2018-02-05 completed
# Processing 91/549: 2018-02-17...
# 2018-02-17 completed
# Processing 92/549: 2018-02-22...
# 2018-02-22 completed
# Processing 93/549: 2018-03-01...
# 2018-03-01 completed
# Processing 94/549: 2018-03-06...
# 2018-03-06 completed
# Processing 95/549: 2018-03-13...
# 2018-03-13 completed
# Processing 96/549: 2018-03-18...
# 2018-03-18 completed
# Processing 97/549: 2018-03-25...
# 2018-03-25 completed
# Processing 98/549: 2018-03-30...
# 2018-03-30 completed
# Processing 99/549: 2018-04-06...
# 2018-04-06 completed
# Processing 100/549: 2018-04-11...
# 2018-04-11 completed
# Processing 101/549: 2018-04-18...
# 2018-04-18 completed
# Processing 102/549: 2018-04-23...
# 2018-04-23 completed
# Processing 103/549: 2018-04-30...
# 2018-04-30 completed
# Processing 104/549: 2018-05-05...
# 2018-05-05 completed
# Processing 105/549: 2018-05-12...
# 2018-05-12 completed
# Processing 106/549: 2018-05-17...
# 2018-05-17 completed
# Processing 107/549: 2018-05-24...
# 2018-05-24 completed
# Processing 108/549: 2018-05-29...
# 2018-05-29 completed
# Processing 109/549: 2018-06-05...
# 2018-06-05 completed
# Processing 110/549: 2018-06-10...
# 2018-06-10 completed
# Processing 111/549: 2018-06-17...
# 2018-06-17 completed
# Processing 112/549: 2018-06-22...
# 2018-06-22 completed
# Processing 113/549: 2018-06-29...
# 2018-06-29 completed
# Processing 114/549: 2018-07-04...
# 2018-07-04 completed
# Processing 115/549: 2018-07-11...
# 2018-07-11 completed
# Processing 116/549: 2018-07-16...
# 2018-07-16 completed
# Processing 117/549: 2018-07-23...
# 2018-07-23 completed
# Processing 118/549: 2018-07-28...
# 2018-07-28 completed
# Processing 119/549: 2018-08-04...
# 2018-08-04 completed
# Processing 120/549: 2018-08-09...
# 2018-08-09 completed
# Processing 121/549: 2018-08-16...
# 2018-08-16 completed
# Processing 122/549: 2018-08-21...
# 2018-08-21 completed
# Processing 123/549: 2018-09-02...
# 2018-09-02 completed
# Processing 124/549: 2018-09-09...
# 2018-09-09 completed
# Processing 125/549: 2018-09-14...
# 2018-09-14 completed
# Processing 126/549: 2018-09-15...
# 2018-09-15 completed
# Processing 127/549: 2018-09-21...
# 2018-09-21 completed
# Processing 128/549: 2018-09-26...
# 2018-09-26 completed
# Processing 129/549: 2018-10-03...
# 2018-10-03 completed
# Processing 130/549: 2018-10-08...
# 2018-10-08 completed
# Processing 131/549: 2018-10-14...
# 2018-10-14 completed
# Processing 132/549: 2018-10-15...
# 2018-10-15 completed
# Processing 133/549: 2018-10-20...
# 2018-10-20 completed
# Processing 134/549: 2018-10-27...
# 2018-10-27 completed
# Processing 135/549: 2018-11-01...
# 2018-11-01 completed
# Processing 136/549: 2018-11-08...
# 2018-11-08 completed
# Processing 137/549: 2018-11-13...
# 2018-11-13 completed
# Processing 138/549: 2018-11-20...
# 2018-11-20 completed
# Processing 139/549: 2018-11-25...
# 2018-11-25 completed
# Processing 140/549: 2018-12-02...
# 2018-12-02 completed
# Processing 141/549: 2018-12-14...
# 2018-12-14 completed
# Processing 142/549: 2018-12-19...
# 2018-12-19 completed
# Processing 143/549: 2018-12-26...
# 2018-12-26 completed
# Processing 144/549: 2018-12-31...
# 2018-12-31 completed
# Processing 145/549: 2019-01-07...
# 2019-01-07 completed
# Processing 146/549: 2019-01-12...
# 2019-01-12 completed
# Processing 147/549: 2019-01-19...
# 2019-01-19 completed
# Processing 148/549: 2019-01-24...
# 2019-01-24 completed
# Processing 149/549: 2019-01-31...
# 2019-01-31 completed
# Processing 150/549: 2019-02-12...
# 2019-02-12 completed
# Processing 151/549: 2019-02-17...
# 2019-02-17 completed
# Processing 152/549: 2019-02-24...
# 2019-02-24 completed
# Processing 153/549: 2019-03-01...
# 2019-03-01 completed
# Processing 154/549: 2019-03-08...
# 2019-03-08 completed
# Processing 155/549: 2019-03-13...
# 2019-03-13 completed
# Processing 156/549: 2019-03-20...
# 2019-03-20 completed
# Processing 157/549: 2019-03-25...
# 2019-03-25 completed
# Processing 158/549: 2019-04-01...
# 2019-04-01 completed
# Processing 159/549: 2019-04-06...
# 2019-04-06 completed
# Processing 160/549: 2019-04-13...
# 2019-04-13 completed
# Processing 161/549: 2019-04-18...
# 2019-04-18 completed
# Processing 162/549: 2019-04-25...
# 2019-04-25 completed
# Processing 163/549: 2019-04-30...
# 2019-04-30 completed
# Processing 164/549: 2019-05-07...
# 2019-05-07 completed
# Processing 165/549: 2019-05-12...
# 2019-05-12 completed
# Processing 166/549: 2019-05-19...
# 2019-05-19 completed
# Processing 167/549: 2019-05-31...
# 2019-05-31 completed
# Processing 168/549: 2019-06-05...
# 2019-06-05 completed
# Processing 169/549: 2019-06-12...
# 2019-06-12 completed
# Processing 170/549: 2019-06-17...
# 2019-06-17 completed
# Processing 171/549: 2019-06-24...
# 2019-06-24 completed
# Processing 172/549: 2019-06-29...
# 2019-06-29 completed
# Processing 173/549: 2019-07-06...
# 2019-07-06 completed
# Processing 174/549: 2019-07-11...
# 2019-07-11 completed
# Processing 175/549: 2019-07-18...
# 2019-07-18 completed
# Processing 176/549: 2019-07-23...
# 2019-07-23 completed
# Processing 177/549: 2019-07-30...
# 2019-07-30 completed
# Processing 178/549: 2019-08-04...
# 2019-08-04 completed
# Processing 179/549: 2019-08-11...
# 2019-08-11 completed
# Processing 180/549: 2019-08-16...
# 2019-08-16 completed
# Processing 181/549: 2019-08-23...
# 2019-08-23 completed
# Processing 182/549: 2019-08-28...
# 2019-08-28 completed
# Processing 183/549: 2019-09-03...
# 2019-09-03 completed
# Processing 184/549: 2019-09-04...
# 2019-09-04 completed
# Processing 185/549: 2019-09-09...
# 2019-09-09 completed
# Processing 186/549: 2019-09-16...
# 2019-09-16 completed
# Processing 187/549: 2019-09-21...
# 2019-09-21 completed
# Processing 188/549: 2019-09-28...
# 2019-09-28 completed
# Processing 189/549: 2019-10-03...
# 2019-10-03 completed
# Processing 190/549: 2019-10-10...
# 2019-10-10 completed
# Processing 191/549: 2019-10-15...
# 2019-10-15 completed
# Processing 192/549: 2019-10-22...
# 2019-10-22 completed
# Processing 193/549: 2019-10-27...
# 2019-10-27 completed
# Processing 194/549: 2019-11-03...
# 2019-11-03 completed
# Processing 195/549: 2019-11-08...
# 2019-11-08 completed
# Processing 196/549: 2019-11-15...
# 2019-11-15 completed
# Processing 197/549: 2019-11-20...
# 2019-11-20 completed
# Processing 198/549: 2019-11-27...
# 2019-11-27 completed
# Processing 199/549: 2019-12-02...
# 2019-12-02 completed
# Processing 200/549: 2019-12-09...
# 2019-12-09 completed
# Processing 201/549: 2019-12-14...
# 2019-12-14 completed
# Processing 202/549: 2019-12-21...
# 2019-12-21 completed
# Processing 203/549: 2019-12-26...
# 2019-12-26 completed
# Processing 204/549: 2020-01-02...
# 2020-01-02 completed
# Processing 205/549: 2020-01-07...
# 2020-01-07 completed
# Processing 206/549: 2020-01-14...
# 2020-01-14 completed
# Processing 207/549: 2020-01-26...
# 2020-01-26 completed
# Processing 208/549: 2020-01-31...
# 2020-01-31 completed
# Processing 209/549: 2020-02-07...
# 2020-02-07 completed
# Processing 210/549: 2020-02-12...
# 2020-02-12 completed
# Processing 211/549: 2020-02-19...
# 2020-02-19 completed
# Processing 212/549: 2020-02-24...
# 2020-02-24 completed
# Processing 213/549: 2020-03-02...
# 2020-03-02 completed
# Processing 214/549: 2020-03-07...
# 2020-03-07 completed
# Processing 215/549: 2020-03-14...
# 2020-03-14 completed
# Processing 216/549: 2020-03-19...
# 2020-03-19 completed
# Processing 217/549: 2020-03-26...
# 2020-03-26 completed
# Processing 218/549: 2020-03-31...
# 2020-03-31 completed
# Processing 219/549: 2020-04-07...
# 2020-04-07 completed
# Processing 220/549: 2020-04-12...
# 2020-04-12 completed
# Processing 221/549: 2020-04-19...
# 2020-04-19 completed
# Processing 222/549: 2020-04-24...
# 2020-04-24 completed
# Processing 223/549: 2020-05-01...
# 2020-05-01 completed
# Processing 224/549: 2020-05-06...
# 2020-05-06 completed
# Processing 225/549: 2020-05-13...
# 2020-05-13 completed
# Processing 226/549: 2020-05-18...
# 2020-05-18 completed
# Processing 227/549: 2020-05-30...
# 2020-05-30 completed
# Processing 228/549: 2020-06-06...
# 2020-06-06 completed
# Processing 229/549: 2020-06-11...
# 2020-06-11 completed
# Processing 230/549: 2020-06-18...
# 2020-06-18 completed
# Processing 231/549: 2020-06-23...
# 2020-06-23 completed
# Processing 232/549: 2020-06-30...
# 2020-06-30 completed
# Processing 233/549: 2020-07-05...
# 2020-07-05 completed
# Processing 234/549: 2020-07-12...
# 2020-07-12 completed
# Processing 235/549: 2020-07-17...
# 2020-07-17 completed
# Processing 236/549: 2020-07-24...
# 2020-07-24 completed
# Processing 237/549: 2020-07-29...
# 2020-07-29 completed
# Processing 238/549: 2020-08-05...
# 2020-08-05 completed
# Processing 239/549: 2020-08-10...
# 2020-08-10 completed
# Processing 240/549: 2020-08-17...
# 2020-08-17 completed
# Processing 241/549: 2020-08-22...
# 2020-08-22 completed
# Processing 242/549: 2020-08-28...
# 2020-08-28 completed
# Processing 243/549: 2020-08-29...
# 2020-08-29 completed
# Processing 244/549: 2020-08-30...
# 2020-08-30 completed
# Processing 245/549: 2020-09-03...
# 2020-09-03 completed
# Processing 246/549: 2020-09-10...
# 2020-09-10 completed
# Processing 247/549: 2020-09-15...
# 2020-09-15 completed
# Processing 248/549: 2020-09-22...
# 2020-09-22 completed
# Processing 249/549: 2020-09-27...
# 2020-09-27 completed
# Processing 250/549: 2020-10-04...
# 2020-10-04 completed
# Processing 251/549: 2020-10-09...
# 2020-10-09 completed
# Processing 252/549: 2020-10-16...
# 2020-10-16 completed
# Processing 253/549: 2020-10-21...
# 2020-10-21 completed
# Processing 254/549: 2020-10-28...
# 2020-10-28 completed
# Processing 255/549: 2020-11-02...
# 2020-11-02 completed
# Processing 256/549: 2020-11-09...
# 2020-11-09 completed
# Processing 257/549: 2020-11-14...
# 2020-11-14 completed
# Processing 258/549: 2020-11-21...
# 2020-11-21 completed
# Processing 259/549: 2020-11-26...
# 2020-11-26 completed
# Processing 260/549: 2020-12-03...
# 2020-12-03 completed
# Processing 261/549: 2020-12-08...
# 2020-12-08 completed
# Processing 262/549: 2020-12-15...
# 2020-12-15 completed
# Processing 263/549: 2020-12-20...
# 2020-12-20 completed
# Processing 264/549: 2020-12-27...
# 2020-12-27 completed
# Processing 265/549: 2021-01-01...
# 2021-01-01 completed
# Processing 266/549: 2021-01-08...
# 2021-01-08 completed
# Processing 267/549: 2021-01-13...
# 2021-01-13 completed
# Processing 268/549: 2021-01-20...
# 2021-01-20 completed
# Processing 269/549: 2021-01-25...
# 2021-01-25 completed
# Processing 270/549: 2021-02-01...
# 2021-02-01 completed
# Processing 271/549: 2021-02-06...
# 2021-02-06 completed
# Processing 272/549: 2021-02-13...
# 2021-02-13 completed
# Processing 273/549: 2021-02-18...
# 2021-02-18 completed
# Processing 274/549: 2021-02-25...
# 2021-02-25 completed
# Processing 275/549: 2021-03-02...
# 2021-03-02 completed
# Processing 276/549: 2021-03-09...
# 2021-03-09 completed
# Processing 277/549: 2021-03-14...
# 2021-03-14 completed
# Processing 278/549: 2021-03-21...
# 2021-03-21 completed
# Processing 279/549: 2021-03-26...
# 2021-03-26 completed
# Processing 280/549: 2021-04-02...
# 2021-04-02 completed
# Processing 281/549: 2021-04-14...
# 2021-04-14 completed
# Processing 282/549: 2021-04-19...
# 2021-04-19 completed
# Processing 283/549: 2021-04-26...
# 2021-04-26 completed
# Processing 284/549: 2021-05-01...
# 2021-05-01 completed
# Processing 285/549: 2021-05-08...
# 2021-05-08 completed
# Processing 286/549: 2021-05-20...
# 2021-05-20 completed
# Processing 287/549: 2021-05-25...
# 2021-05-25 completed
# Processing 288/549: 2021-06-01...
# 2021-06-01 completed
# Processing 289/549: 2021-06-06...
# 2021-06-06 completed
# Processing 290/549: 2021-06-13...
# 2021-06-13 completed
# Processing 291/549: 2021-06-18...
# 2021-06-18 completed
# Processing 292/549: 2021-06-25...
# 2021-06-25 completed
# Processing 293/549: 2021-07-07...
# 2021-07-07 completed
# Processing 294/549: 2021-07-12...
# 2021-07-12 completed
# Processing 295/549: 2021-07-19...
# 2021-07-19 completed
# Processing 296/549: 2021-07-31...
# 2021-07-31 completed
# Processing 297/549: 2021-08-05...
# 2021-08-05 completed
# Processing 298/549: 2021-08-12...
# 2021-08-12 completed
# Processing 299/549: 2021-08-17...
# 2021-08-17 completed
# Processing 300/549: 2021-08-24...
# 2021-08-24 completed
# Processing 301/549: 2021-08-29...
# 2021-08-29 completed
# Processing 302/549: 2021-09-05...
# 2021-09-05 completed
# Processing 303/549: 2021-09-10...
# 2021-09-10 completed
# Processing 304/549: 2021-09-17...
# 2021-09-17 completed
# Processing 305/549: 2021-09-22...
# 2021-09-22 completed
# Processing 306/549: 2021-09-29...
# 2021-09-29 completed
# Processing 307/549: 2021-10-04...
# 2021-10-04 completed
# Processing 308/549: 2021-10-11...
# 2021-10-11 completed
# Processing 309/549: 2021-10-16...
# 2021-10-16 completed
# Processing 310/549: 2021-10-23...
# 2021-10-23 completed
# Processing 311/549: 2021-10-28...
# 2021-10-28 completed
# Processing 312/549: 2021-11-04...
# 2021-11-04 completed
# Processing 313/549: 2021-11-09...
# 2021-11-09 completed
# Processing 314/549: 2021-11-16...
# 2021-11-16 completed
# Processing 315/549: 2021-11-21...
# 2021-11-21 completed
# Processing 316/549: 2021-11-28...
# 2021-11-28 completed
# Processing 317/549: 2021-12-03...
# 2021-12-03 completed
# Processing 318/549: 2021-12-10...
# 2021-12-10 completed
# Processing 319/549: 2021-12-15...
# 2021-12-15 completed
# Processing 320/549: 2021-12-22...
# 2021-12-22 completed
# Processing 321/549: 2021-12-27...
# 2021-12-27 completed
# Processing 322/549: 2022-01-03...
# 2022-01-03 completed
# Processing 323/549: 2022-01-08...
# 2022-01-08 completed
# Processing 324/549: 2022-01-15...
# 2022-01-15 completed
# Processing 325/549: 2022-01-20...
# 2022-01-20 completed
# Processing 326/549: 2022-01-27...
# 2022-01-27 completed
# Processing 327/549: 2022-02-01...
# 2022-02-01 completed
# Processing 328/549: 2022-02-08...
# 2022-02-08 completed
# Processing 329/549: 2022-02-13...
# 2022-02-13 completed
# Processing 330/549: 2022-02-20...
# 2022-02-20 completed
# Processing 331/549: 2022-02-25...
# 2022-02-25 completed
# Processing 332/549: 2022-03-04...
# 2022-03-04 completed
# Processing 333/549: 2022-03-09...
# 2022-03-09 completed
# Processing 334/549: 2022-03-16...
# 2022-03-16 completed
# Processing 335/549: 2022-03-21...
# 2022-03-21 completed
# Processing 336/549: 2022-03-28...
# 2022-03-28 completed
# Processing 337/549: 2022-04-09...
# 2022-04-09 completed
# Processing 338/549: 2022-04-14...
# 2022-04-14 completed
# Processing 339/549: 2022-04-21...
# 2022-04-21 completed
# Processing 340/549: 2022-04-26...
# 2022-04-26 completed
# Processing 341/549: 2022-05-03...
# 2022-05-03 completed
# Processing 342/549: 2022-05-08...
# 2022-05-08 completed
# Processing 343/549: 2022-05-15...
# 2022-05-15 completed
# Processing 344/549: 2022-05-20...
# 2022-05-20 completed
# Processing 345/549: 2022-05-27...
# 2022-05-27 completed
# Processing 346/549: 2022-06-01...
# 2022-06-01 completed
# Processing 347/549: 2022-06-08...
# 2022-06-08 completed
# Processing 348/549: 2022-06-20...
# 2022-06-20 completed
# Processing 349/549: 2022-06-25...
# 2022-06-25 completed
# Processing 350/549: 2022-07-02...
# 2022-07-02 completed
# Processing 351/549: 2022-07-14...
# 2022-07-14 completed
# Processing 352/549: 2022-07-19...
# 2022-07-19 completed
# Processing 353/549: 2022-07-26...
# 2022-07-26 completed
# Processing 354/549: 2022-07-31...
# 2022-07-31 completed
# Processing 355/549: 2022-08-07...
# 2022-08-07 completed
# Processing 356/549: 2022-08-12...
# 2022-08-12 completed
# Processing 357/549: 2022-08-19...
# 2022-08-19 completed
# Processing 358/549: 2022-08-24...
# 2022-08-24 completed
# Processing 359/549: 2022-08-31...
# 2022-08-31 completed
# Processing 360/549: 2022-09-05...
# 2022-09-05 completed
# Processing 361/549: 2022-09-12...
# 2022-09-12 completed
# Processing 362/549: 2022-09-17...
# 2022-09-17 completed
# Processing 363/549: 2022-09-24...
# 2022-09-24 completed
# Processing 364/549: 2022-09-29...
# 2022-09-29 completed
# Processing 365/549: 2022-10-06...
# 2022-10-06 completed
# Processing 366/549: 2022-10-11...
# 2022-10-11 completed
# Processing 367/549: 2022-10-18...
# 2022-10-18 completed
# Processing 368/549: 2022-10-23...
# 2022-10-23 completed
# Processing 369/549: 2022-10-30...
# 2022-10-30 completed
# Processing 370/549: 2022-11-04...
# 2022-11-04 completed
# Processing 371/549: 2022-11-11...
# 2022-11-11 completed
# Processing 372/549: 2022-11-16...
# 2022-11-16 completed
# Processing 373/549: 2022-11-23...
# 2022-11-23 completed
# Processing 374/549: 2022-11-28...
# 2022-11-28 completed
# Processing 375/549: 2022-12-05...
# 2022-12-05 completed
# Processing 376/549: 2022-12-10...
# 2022-12-10 completed
# Processing 377/549: 2022-12-17...
# 2022-12-17 completed
# Processing 378/549: 2022-12-22...
# 2022-12-22 completed
# Processing 379/549: 2022-12-29...
# 2022-12-29 completed
# Processing 380/549: 2023-01-03...
# 2023-01-03 completed
# Processing 381/549: 2023-01-10...
# 2023-01-10 completed
# Processing 382/549: 2023-01-15...
# 2023-01-15 completed
# Processing 383/549: 2023-01-22...
# 2023-01-22 completed
# Processing 384/549: 2023-01-27...
# 2023-01-27 completed
# Processing 385/549: 2023-02-03...
# 2023-02-03 completed
# Processing 386/549: 2023-02-08...
# 2023-02-08 completed
# Processing 387/549: 2023-02-15...
# 2023-02-15 completed
# Processing 388/549: 2023-02-20...
# 2023-02-20 completed
# Processing 389/549: 2023-02-27...
# 2023-02-27 completed
# Processing 390/549: 2023-03-04...
# 2023-03-04 completed
# Processing 391/549: 2023-03-11...
# 2023-03-11 completed
# Processing 392/549: 2023-03-16...
# 2023-03-16 completed
# Processing 393/549: 2023-03-23...
# 2023-03-23 completed
# Processing 394/549: 2023-03-28...
# 2023-03-28 completed
# Processing 395/549: 2023-04-04...
# 2023-04-04 completed
# Processing 396/549: 2023-04-09...
# 2023-04-09 completed
# Processing 397/549: 2023-04-16...
# 2023-04-16 completed
# Processing 398/549: 2023-04-21...
# 2023-04-21 completed
# Processing 399/549: 2023-04-28...
# 2023-04-28 completed
# Processing 400/549: 2023-05-03...
# 2023-05-03 completed
# Processing 401/549: 2023-05-10...
# 2023-05-10 completed
# Processing 402/549: 2023-05-15...
# 2023-05-15 completed
# Processing 403/549: 2023-05-22...
# 2023-05-22 completed
# Processing 404/549: 2023-05-27...
# 2023-05-27 completed
# Processing 405/549: 2023-06-03...
# 2023-06-03 completed
# Processing 406/549: 2023-06-08...
# 2023-06-08 completed
# Processing 407/549: 2023-06-15...
# 2023-06-15 completed
# Processing 408/549: 2023-06-20...
# 2023-06-20 completed
# Processing 409/549: 2023-06-27...
# 2023-06-27 completed
# Processing 410/549: 2023-07-09...
# 2023-07-09 completed
# Processing 411/549: 2023-07-14...
# 2023-07-14 completed
# Processing 412/549: 2023-07-21...
# 2023-07-21 completed
# Processing 413/549: 2023-08-07...
# 2023-08-07 completed
# Processing 414/549: 2023-08-19...
# 2023-08-19 completed
# Processing 415/549: 2023-08-26...
# 2023-08-26 completed
# Processing 416/549: 2023-08-31...
# 2023-08-31 completed
# Processing 417/549: 2023-09-07...
# 2023-09-07 completed
# Processing 418/549: 2023-09-12...
# 2023-09-12 completed
# Processing 419/549: 2023-09-19...
# 2023-09-19 completed
# Processing 420/549: 2023-09-24...
# 2023-09-24 completed
# Processing 421/549: 2023-10-01...
# 2023-10-01 completed
# Processing 422/549: 2023-10-06...
# 2023-10-06 completed
# Processing 423/549: 2023-10-13...
# 2023-10-13 completed
# Processing 424/549: 2023-10-18...
# 2023-10-18 completed
# Processing 425/549: 2023-10-25...
# 2023-10-25 completed
# Processing 426/549: 2023-10-30...
# 2023-10-30 completed
# Processing 427/549: 2023-11-06...
# 2023-11-06 completed
# Processing 428/549: 2023-11-11...
# 2023-11-11 completed
# Processing 429/549: 2023-11-18...
# 2023-11-18 completed
# Processing 430/549: 2023-11-23...
# 2023-11-23 completed
# Processing 431/549: 2023-11-30...
# 2023-11-30 completed
# Processing 432/549: 2023-12-05...
# 2023-12-05 completed
# Processing 433/549: 2023-12-12...
# 2023-12-12 completed
# Processing 434/549: 2023-12-17...
# 2023-12-17 completed
# Processing 435/549: 2023-12-24...
# 2023-12-24 completed
# Processing 436/549: 2023-12-29...
# 2023-12-29 completed
# Processing 437/549: 2024-01-05...
# 2024-01-05 completed
# Processing 438/549: 2024-01-10...
# 2024-01-10 completed
# Processing 439/549: 2024-01-17...
# 2024-01-17 completed
# Processing 440/549: 2024-01-22...
# 2024-01-22 completed
# Processing 441/549: 2024-01-29...
# 2024-01-29 completed
# Processing 442/549: 2024-02-03...
# 2024-02-03 completed
# Processing 443/549: 2024-02-10...
# 2024-02-10 completed
# Processing 444/549: 2024-02-15...
# 2024-02-15 completed
# Processing 445/549: 2024-02-22...
# 2024-02-22 completed
# Processing 446/549: 2024-02-27...
# 2024-02-27 completed
# Processing 447/549: 2024-03-05...
# 2024-03-05 completed
# Processing 448/549: 2024-03-10...
# 2024-03-10 completed
# Processing 449/549: 2024-03-17...
# 2024-03-17 completed
# Processing 450/549: 2024-03-22...
# 2024-03-22 completed
# Processing 451/549: 2024-03-29...
# 2024-03-29 completed
# Processing 452/549: 2024-04-03...
# 2024-04-03 completed
# Processing 453/549: 2024-04-10...
# 2024-04-10 completed
# Processing 454/549: 2024-04-15...
# 2024-04-15 completed
# Processing 455/549: 2024-04-22...
# 2024-04-22 completed
# Processing 456/549: 2024-04-27...
# 2024-04-27 completed
# Processing 457/549: 2024-05-04...
# 2024-05-04 completed
# Processing 458/549: 2024-05-09...
# 2024-05-09 completed
# Processing 459/549: 2024-05-16...
# 2024-05-16 completed
# Processing 460/549: 2024-05-28...
# 2024-05-28 completed
# Processing 461/549: 2024-06-02...
# 2024-06-02 completed
# Processing 462/549: 2024-06-09...
# 2024-06-09 completed
# Processing 463/549: 2024-06-14...
# 2024-06-14 completed
# Processing 464/549: 2024-06-21...
# 2024-06-21 completed
# Processing 465/549: 2024-06-26...
# 2024-06-26 completed
# Processing 466/549: 2024-07-03...
# 2024-07-03 completed
# Processing 467/549: 2024-07-08...
# 2024-07-08 completed
# Processing 468/549: 2024-07-15...
# 2024-07-15 completed
# Processing 469/549: 2024-07-20...
# 2024-07-20 completed
# Processing 470/549: 2024-07-27...
# 2024-07-27 completed
# Processing 471/549: 2024-08-01...
# 2024-08-01 completed
# Processing 472/549: 2024-08-08...
# 2024-08-08 completed
# Processing 473/549: 2024-08-13...
# 2024-08-13 completed
# Processing 474/549: 2024-08-20...
# 2024-08-20 completed
# Processing 475/549: 2024-09-01...
# 2024-09-01 completed
# Processing 476/549: 2024-09-06...
# 2024-09-06 completed
# Processing 477/549: 2024-09-13...
# 2024-09-13 completed
# Processing 478/549: 2024-09-18...
# 2024-09-18 completed
# Processing 479/549: 2024-09-25...
# 2024-09-25 completed
# Processing 480/549: 2024-09-30...
# 2024-09-30 completed
# Processing 481/549: 2024-10-07...
# 2024-10-07 completed
# Processing 482/549: 2024-10-12...
# 2024-10-12 completed
# Processing 483/549: 2024-10-19...
# 2024-10-19 completed
# Processing 484/549: 2024-10-24...
# 2024-10-24 completed
# Processing 485/549: 2024-10-31...
# 2024-10-31 completed
# Processing 486/549: 2024-11-05...
# 2024-11-05 completed
# Processing 487/549: 2024-11-12...
# 2024-11-12 completed
# Processing 488/549: 2024-11-17...
# 2024-11-17 completed
# Processing 489/549: 2024-11-24...
# 2024-11-24 completed
# Processing 490/549: 2024-11-29...
# 2024-11-29 completed
# Processing 491/549: 2024-12-06...
# 2024-12-06 completed
# Processing 492/549: 2024-12-11...
# 2024-12-11 completed
# Processing 493/549: 2024-12-18...
# 2024-12-18 completed
# Processing 494/549: 2024-12-23...
# 2024-12-23 completed
# Processing 495/549: 2024-12-30...
# 2024-12-30 completed
# Processing 496/549: 2025-01-04...
# 2025-01-04 completed
# Processing 497/549: 2025-01-11...
# 2025-01-11 completed
# Processing 498/549: 2025-01-16...
# 2025-01-16 completed
# Processing 499/549: 2025-01-17...
# 2025-01-17 completed
# Processing 500/549: 2025-01-23...
# 2025-01-23 completed
# Processing 501/549: 2025-01-28...
# 2025-01-28 completed
# Processing 502/549: 2025-01-29...
# 2025-01-29 completed
# Processing 503/549: 2025-02-04...
# 2025-02-04 completed
# Processing 504/549: 2025-02-05...
# 2025-02-05 completed
# Processing 505/549: 2025-02-09...
# 2025-02-09 completed
# Processing 506/549: 2025-02-16...
# 2025-02-16 completed
# Processing 507/549: 2025-02-21...
# 2025-02-21 completed
# Processing 508/549: 2025-02-22...
# 2025-02-22 completed
# Processing 509/549: 2025-02-28...
# 2025-02-28 completed
# Processing 510/549: 2025-03-05...
# 2025-03-05 completed
# Processing 511/549: 2025-03-12...
# 2025-03-12 completed
# Processing 512/549: 2025-03-17...
# 2025-03-17 completed
# Processing 513/549: 2025-03-24...
# 2025-03-24 completed
# Processing 514/549: 2025-03-29...
# 2025-03-29 completed
# Processing 515/549: 2025-04-05...
# 2025-04-05 completed
# Processing 516/549: 2025-04-10...
# 2025-04-10 completed
# Processing 517/549: 2025-04-11...
# 2025-04-11 completed
# Processing 518/549: 2025-04-17...
# 2025-04-17 completed
# Processing 519/549: 2025-04-18...
# 2025-04-18 completed
# Processing 520/549: 2025-04-22...
# 2025-04-22 completed
# Processing 521/549: 2025-04-23...
# 2025-04-23 completed
# Processing 522/549: 2025-04-29...
# 2025-04-29 completed
# Processing 523/549: 2025-04-30...
# 2025-04-30 completed
# Processing 524/549: 2025-05-04...
# 2025-05-04 completed
# Processing 525/549: 2025-05-11...
# 2025-05-11 completed
# Processing 526/549: 2025-05-16...
# 2025-05-16 completed
# Processing 527/549: 2025-05-23...
# 2025-05-23 completed
# Processing 528/549: 2025-05-28...
# 2025-05-28 completed
# Processing 529/549: 2025-06-04...
# 2025-06-04 completed
# Processing 530/549: 2025-06-09...
# 2025-06-09 completed
# Processing 531/549: 2025-06-16...
# 2025-06-16 completed
# Processing 532/549: 2025-06-21...
# 2025-06-21 completed
# Processing 533/549: 2025-06-28...
# 2025-06-28 completed
# Processing 534/549: 2025-07-03...
# 2025-07-03 completed
# Processing 535/549: 2025-07-10...
# 2025-07-10 completed
# Processing 536/549: 2025-07-15...
# 2025-07-15 completed
# Processing 537/549: 2025-07-22...
# 2025-07-22 completed
# Processing 538/549: 2025-07-27...
# 2025-07-27 completed
# Processing 539/549: 2025-08-03...
# 2025-08-03 completed
# Processing 540/549: 2025-08-08...
# 2025-08-08 completed
# Processing 541/549: 2025-08-15...
# 2025-08-15 completed
# Processing 542/549: 2025-08-20...
# 2025-08-20 completed
# Processing 543/549: 2025-08-27...
# 2025-08-27 completed
# Processing 544/549: 2025-09-01...
# 2025-09-01 completed
# Processing 545/549: 2025-09-08...
# 2025-09-08 completed
# Processing 546/549: 2025-09-13...
# 2025-09-13 completed
# Processing 547/549: 2025-09-20...
# 2025-09-20 completed
# Processing 548/549: 2025-09-25...
# 2025-09-25 completed
# Processing 549/549: 2025-10-02...
# 2025-10-02 completed
#
# Successfully processed 549 dates

# %% [markdown]
# ### Export Combined Results

# %%
if all_results:
    print("Combining all results (server-side)...")

    # Combine on the server to avoid recursion
    combined_collection = ee.FeatureCollection(all_results).flatten()

    # Export
    task = ee.batch.Export.table.toDrive(
        collection=combined_collection,
        description=f'Chesapeake_SAR_Multi_Date_{len(successful_dates)}_dates',
        fileFormat='CSV'
    )

    task.start()
    print(f'Export started! Processing {len(successful_dates)} dates.')
else:
    print('No results to export.')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Combining all results (server-side)...
# Export started! Processing 549 dates.

# %%
#Print summary
print(f"\nSUMMARY:")
print(f"Total available dates: {len(available_dates)}")
print(f"Dates processed: {len(dates_to_process)}")
print(f"Successful: {len(successful_dates)}")
print(f"Failed: {len(dates_to_process) - len(successful_dates)}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# SUMMARY:
# Total available dates: 549
# Dates processed: 549
# Successful: 549
# Failed: 0

# %% [markdown]
# Time Period, Data Collections, Variables
# To conduct our analysis, we begin by defining the time period and identifying the necessary data collections. We specify the start and end dates for the analysis, set up relevant feature collections, and initialize variables essential for soil erosion analysis. This includes:
#
# * Time Period: Establishing the time frame using start and end dates to define the duration of the analysis.
# * Data Collections: Selecting and defining  collections such as validated reservoirs and catchments that are crucial for our study.
# * Variables: Setting up variables to manage VV,VH, errors, and date lists for time series analysis.
#
# These initial setups enable us to retrieve and process satellite imagery, compute various environmental factors.
